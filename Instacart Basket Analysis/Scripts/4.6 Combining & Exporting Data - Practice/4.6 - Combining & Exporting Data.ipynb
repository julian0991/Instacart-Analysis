# %%
import pandas as pd
import numpy as np
import os

# %%
df_ords_prior1 = pd.read_csv(r'/Users/julianwere/Documents/01-2022/Instacart Basket Analysis/Data/Original Data/order_products__prior.csv', index_col = False)

# %%
path = r'/Users/julianwere/Documents/01-2022/Instacart Basket Analysis'

# %%
df_ords2 = pd.read_csv(r'/Users/julianwere/Documents/01-2022/Instacart Basket Analysis/Data/Prepared Data/orders_cleaned.csv', index_col = False)

# %%
#check the output

# %%
df_ords_prior1.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
#check the output

# %%
df_ords2.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0           0   2539329        1    prior             1          2
# 1           1   2398795        1    prior             2          3
# 2           2    473747        1    prior             3          3
# 3           3   2254736        1    prior             4          4
# 4           4    431534        1    prior             5          4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_ords2.drop('eval_set', axis=1)
# Out:
#          Unnamed: 0  order_id  user_id  order_number  order_dow  \
# 0                 0   2539329        1             1          2
# 1                 1   2398795        1             2          3
# 2                 2    473747        1             3          3
# 3                 3   2254736        1             4          4
# 4                 4    431534        1             5          4
# ...             ...       ...      ...           ...        ...
# 3421078     3421078   2266710   206209            10          5
# 3421079     3421079   1854736   206209            11          4
# 3421080     3421080    626363   206209            12          1
# 3421081     3421081   2977660   206209            13          1
# 3421082     3421082    272231   206209            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# ...

# %%
df_ords2.shape
# Out:
# (3421083, 8)

# %%
df_merged_large = df_ords2.merge(df_ords_prior1, on = 'order_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0           0   2539329        1    prior             1          2
# 1           0   2539329        1    prior             1          2
# 2           0   2539329        1    prior             1          2
# 3           0   2539329        1    prior             1          2
# 4           0   2539329        1    prior             1          2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged_large.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_combined.pkl'))
